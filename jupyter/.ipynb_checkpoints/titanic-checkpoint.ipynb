# %%
path ='/home/git/PycharmProjects/github/jupyter/data/Titanic.csv'
import pandas as pd

df = pd.read_csv(path)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.Embarked[df.Embarked.isnull()] = df.Embarked.dropna().mode().values
# Out:
# /root/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.Cabin[df.Cabin.isnull()]='U0'
# Out:
# /root/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
age_df = df[['Age','Survived','Fare', 'Parch', 'SibSp', 'Pclass']]

# %%
age_df
# Out:
#       Age  Survived      Fare  Parch  SibSp  Pclass
# 0    22.0         0    7.2500      0      1       3
# 1    38.0         1   71.2833      0      1       1
# 2    26.0         1    7.9250      0      0       3
# 3    35.0         1   53.1000      0      1       1
# 4    35.0         0    8.0500      0      0       3
# 5     NaN         0    8.4583      0      0       3
# 6    54.0         0   51.8625      0      0       1
# 7     2.0         0   21.0750      1      3       3
# 8    27.0         1   11.1333      2      0       3
# 9    14.0         1   30.0708      0      1       2
# 10    4.0         1   16.7000      1      1       3
# 11   58.0         1   26.5500      0      0       1
# 12   20.0         0    8.0500      0      0       3
# 13   39.0         0   31.2750      5      1       3
# 14   14.0         0    7.8542      0      0       3
# 15   55.0         1   16.0000      0      0       2
# 16    2.0         0   29.1250      1      4       3
# ...

# %%
age_df_notnull = age_df.loc[(df.Age.notnull())]
age_df_isnull = age_df.loc[(df.Age.isnull())]

# %%
age_df_notnull
# Out:
#       Age  Survived      Fare  Parch  SibSp  Pclass
# 0    22.0         0    7.2500      0      1       3
# 1    38.0         1   71.2833      0      1       1
# 2    26.0         1    7.9250      0      0       3
# 3    35.0         1   53.1000      0      1       1
# 4    35.0         0    8.0500      0      0       3
# 6    54.0         0   51.8625      0      0       1
# 7     2.0         0   21.0750      1      3       3
# 8    27.0         1   11.1333      2      0       3
# 9    14.0         1   30.0708      0      1       2
# 10    4.0         1   16.7000      1      1       3
# 11   58.0         1   26.5500      0      0       1
# 12   20.0         0    8.0500      0      0       3
# 13   39.0         0   31.2750      5      1       3
# 14   14.0         0    7.8542      0      0       3
# 15   55.0         1   16.0000      0      0       2
# 16    2.0         0   29.1250      1      4       3
# 18   31.0         0   18.0000      0      1       3
# ...

# %%
age_df_isnull
# Out:
#      Age  Survived      Fare  Parch  SibSp  Pclass
# 5    NaN         0    8.4583      0      0       3
# 17   NaN         1   13.0000      0      0       2
# 19   NaN         1    7.2250      0      0       3
# 26   NaN         0    7.2250      0      0       3
# 28   NaN         1    7.8792      0      0       3
# 29   NaN         0    7.8958      0      0       3
# 31   NaN         1  146.5208      0      1       1
# 32   NaN         1    7.7500      0      0       3
# 36   NaN         1    7.2292      0      0       3
# 42   NaN         0    7.8958      0      0       3
# 45   NaN         0    8.0500      0      0       3
# 46   NaN         0   15.5000      0      1       3
# 47   NaN         1    7.7500      0      0       3
# 48   NaN         0   21.6792      0      2       3
# 55   NaN         1   35.5000      0      0       1
# 64   NaN         0   27.7208      0      0       1
# 65   NaN         1   15.2458      1      1       3
# ...

# %%
X = age_df_notnull.values[:,1:]
Y = age_df_notnull.values[:,0]

# %%
X
# Out:
# array([[  0.    ,   7.25  ,   0.    ,   1.    ,   3.    ],
#        [  1.    ,  71.2833,   0.    ,   1.    ,   1.    ],
#        [  1.    ,   7.925 ,   0.    ,   0.    ,   3.    ],
#        ...,
#        [  1.    ,  30.    ,   0.    ,   0.    ,   1.    ],
#        [  1.    ,  30.    ,   0.    ,   0.    ,   1.    ],
#        [  0.    ,   7.75  ,   0.    ,   0.    ,   3.    ]])

# %%
Y
# Out:
# array([ 22.  ,  38.  ,  26.  ,  35.  ,  35.  ,  54.  ,   2.  ,  27.  ,
#         14.  ,   4.  ,  58.  ,  20.  ,  39.  ,  14.  ,  55.  ,   2.  ,
#         31.  ,  35.  ,  34.  ,  15.  ,  28.  ,   8.  ,  38.  ,  19.  ,
#         40.  ,  66.  ,  28.  ,  42.  ,  21.  ,  18.  ,  14.  ,  40.  ,
#         27.  ,   3.  ,  19.  ,  18.  ,   7.  ,  21.  ,  49.  ,  29.  ,
#         65.  ,  21.  ,  28.5 ,   5.  ,  11.  ,  22.  ,  38.  ,  45.  ,
#          4.  ,  29.  ,  19.  ,  17.  ,  26.  ,  32.  ,  16.  ,  21.  ,
#         26.  ,  32.  ,  25.  ,   0.83,  30.  ,  22.  ,  29.  ,  28.  ,
#         17.  ,  33.  ,  16.  ,  23.  ,  24.  ,  29.  ,  20.  ,  46.  ,
#         26.  ,  59.  ,  71.  ,  23.  ,  34.  ,  34.  ,  28.  ,  21.  ,
#         33.  ,  37.  ,  28.  ,  21.  ,  38.  ,  47.  ,  14.5 ,  22.  ,
#         20.  ,  17.  ,  21.  ,  70.5 ,  29.  ,  24.  ,   2.  ,  21.  ,
#         32.5 ,  32.5 ,  54.  ,  12.  ,  24.  ,  45.  ,  33.  ,  20.  ,
# ...

# %%
from  sklearn.ensemble import RandomForestRegressor

# %%
rfr =  RandomForestRegressor(n_estimators = 1000,n_jobs=1)
rfr.fit(X,Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
predictAge = rfr.predict(age_df_isnull.values[:,1:])

# %%
len(predictAge)
# Out:
# 177

# %%
df.loc[df.Age.isnull(),'Age'] = predictAge

# %%
df.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
path
# Out:
# '/home/git/PycharmProjects/github/jupyter/data/Titanic.csv'

# %%
import pandas as pd
path_train = '/home/git/PycharmProjects/github/jupyter/data/Titanic_train.csv'
path_test = '/home/git/PycharmProjects/github/jupyter/data/Titanic_test.csv'

# %%
train = pd.read_csv(path_train)
test = pd.read_csv(path_test)

# %%
selected_feature = ['Pclass','Sex','Age','SibSp','Parch',
                   'Embarked']

X_train = train[selected_feature]
X_test = test[selected_feature]

Y_train = train['Survived']

# %%
X_train['Embarked'].fillna('S', inplace = True)
X_test['Embarked'].fillna('S', inplace = True)
X_train['Age'].fillna(X_train['Age'].mean(), inplace = True)
X_test['Age'].fillna(X_test['Age'].mean(), inplace = True)
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
# Pclass      891 non-null int64
# Sex         891 non-null object
# Age         891 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Embarked    891 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 41.8+ KB

# %%
from sklearn.feature_extraction import DictVectorizer
dict_vec = DictVectorizer(sparse = False)

# %%
X_train
# Out:
#      Pclass     Sex        Age  SibSp  Parch Embarked
# 0         3    male  22.000000      1      0        S
# 1         1  female  38.000000      1      0        C
# 2         3  female  26.000000      0      0        S
# 3         1  female  35.000000      1      0        S
# 4         3    male  35.000000      0      0        S
# 5         3    male  29.699118      0      0        Q
# 6         1    male  54.000000      0      0        S
# 7         3    male   2.000000      3      1        S
# 8         3  female  27.000000      0      2        S
# 9         2  female  14.000000      1      0        C
# 10        3  female   4.000000      1      1        S
# 11        1  female  58.000000      0      0        S
# 12        3    male  20.000000      0      0        S
# 13        3    male  39.000000      1      5        S
# 14        3  female  14.000000      0      0        S
# 15        2  female  55.000000      0      0        S
# ...

# %%
a = X_train = dict_vec.fit_transform(X_train.to_dict(orient = 'record'))
