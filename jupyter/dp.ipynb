# %%
import urllib2
from bs4 import BeautifulSoup
url='http://www.dianping.com/search/category/2/10'
response = urllib2.urlopen(url)
soup = BeautifulSoup(response,'lxml')

# %%
page =soup.find(class_='page')

# %%
type(page)
pages = [ i.text  for i in page.find_all('a')]
pages = pages[-2]
print(pages)
# Out:
# 50

# %%
url="http://www.dianping.com/search/category/2/10/p9?aid=69698308%2C38230595%2C58935140%2C67056533%2C90003115%2C23308292&cpt=69698308%2C38230595%2C58935140%2C67056533%2C90003115&tc=1"

response = urllib2.urlopen(url)
soup = BeautifulSoup(response,'lxml')

# %%
#<div class="pic" >
pics = soup.find_all('div',class_='pic')

print(len(pics))
# Out:
# 15

# %%
print(pics[1])
# Out:
# <div class="pic">
# <a href="http://www.dianping.com/shop/93253021" onclick="LXAnalytics('moduleClick', 'shoppic')" rel="nofollow" target="_blank" title="">
# <img alt="面呈牛王" data-src="http://p1.meituan.net/mogu/3d9fdea86629952cb2fde25a0c3b071e64886.jpg%40340w_255h_1e_1c_1l%7Cwatermark%3D1%26%26r%3D1%26p%3D9%26x%3D2%26y%3D2%26relative%3D1%26o%3D20" title="面呈牛王"/>
# </a>
# </div>

# %%
url = 'http://www.dianping.com/shop/93253021'
response = urllib2.urlopen(url)
soup = BeautifulSoup(response,'lxml')

#<div class="breadcrumb">
# breadcrumb = soup.find('div',class_='breadcrumb')

# print(breadcrumb)

# %%
import requests
payload =  {
'Accept:text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
'Accept-Encoding:gzip, deflate
'Accept-Language:zh-CN,zh;q=0.8
'Cache-Control:max-age=0
'Connection:keep-alive
'Cookie:_lxsdk_cuid=15fa0821e51c8-0e8acb8843318a-5d153b16-100200-15fa0821e52c8; _lxsdk=15fa0821e51c8-0e8acb8843318a-5d153b16-100200-15fa0821e52c8; _hc.v=3db1ecad-3b57-f91f-d89c-b89ef351f7c0.1510226403; JSESSIONID=92DD62BF365350ED098263E0ED34F1A6; aburl=1; cye=beijing; cy=2; _lxsdk_s=15fa0821e53-e69-343-4c5%7C%7C56
'Host:www.dianping.com
'Upgrade-Insecure-Requests:1
'User-Agent':Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.79 Safari/537.36
}

r = requests.post(url, params=payload)

# %%
print(response)
# Out:
# <Response [403]>

# %%
import urllib2
import urllib

url = 'http://www.dianping.com/shop/93253021'
host = 'http://www.dianping.com'
#自定义UA头部，直接用即可，不用理解细节
user_agent = 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.89 Safari/537.36'
headers = {'User-Agent':user_agent}
request = urllib2.Request(url, headers = headers)                               #发送网络请求
response = urllib2.urlopen(request)

# %%
print(response.headers)
dir(response)
print(' '.join(response.readlines()))
# Out:
# Date: Fri, 10 Nov 2017 02:14:12 GMT
# Content-Type: text/html;charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# Vary: Accept-Encoding
# Vary: User-Agent, Accept-Encoding
# ETag: "6df883332633225410e876c12a17676e"
# Last-Modified: Thu, 09 Nov 2017 07:22:45 GMT
# X-Mss-Trace-Id: 1450748829014212393
# Pragma: no-cache
# Cache-Control: no-cache
# Server: DPweb
#
# <!DOCTYPE html>
#  <html>
#      <head>
#          <link rel="icon"  type="image/x-icon"  href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico">
#          <link rel="shortcut icon" type="image/x-icon" href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico" >
#          <link rel="apple-touch-icon" href="//www.dpfile.com/s/res/app-touch-icon.89213f53ed66e1693e4b6aeedd355349.png">
#          <link rel="apple-touch-icon" sizes="76x76" href="//www.dpfile.com/s/res/app-touch-icon-76x76.6399ce382f3e0584a6b07599cbeb3bcb.png">
# ...
